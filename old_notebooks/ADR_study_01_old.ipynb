# %% [markdown]
# # Investigation 01: Spreading Factor Assignment Strategy for Coverage and Capacity Flexible trade-off
#
# ### Authors : Luiz (UFJF), Álvaro (UFJF), Jessika (UFRN), Vicente Sousa (UFRN)
#
# **Targets:**
# - HOWTO material to download, configure and compile the code;
# - HOWTO material to create, run and plot simulations results (including Python scripts);
# - Preliminaly analyses of simulation results.

# %% [markdown]
# # Getting started
#
#
# ### Download Process
#
# - To download this repository, please, type in the terminal:
#
# ```bash
# git clone https://github.com/vicentesousa/ns-3-lora-gppcom.git
# ```
#
# - To go to the code directory, please, type:
#
# ```bash
# cd ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/
# ```
# - To configure, type:
#
# ```bash
# CXXFLAGS="-Wall -g -O0" ./waf --build-profile=debug --disable-examples --disable-tests --disable-python configure
# ```
#
# - To compile, type:
#
# ```bash
# ./waf
# ```
#
# ### Manual installation (optional)
#
# The script **ns3_full_installation.sh** was built to automatically install the code following the three steps:
# - Download and solve the dependences;
# - Download the ns-3.29 code;
# - Download the LoRaWAN ns-3 module (from **https://github.com/signetlabdei/lorawan**)
# - Merge codes from ns-3.29 and LoRaWAN ns-3 module repositories;
# - Add ur changes with new ADR codes (from **LoRa-Luiz-vicente** folder).
#
# The script **ns3_full_installation.sh** should be called inside the folder **ns-3-lora-gppcom** (directory of this repository). However, this script has already been executed, with all contents generated and commited into the repository. So, for sake of simplicity, you do not need to repeat its execution every repository clonning.

# %% [markdown]
# # Simulation Campaings (creation, run and plot)
#
# Our processo to create, run and plot a simulation campaign is completely based on **yaml** files. In this file, a set of parameters is definied as well as the target parameter to a **parametric evaluation**. Such parametric evaluation allows for the analyses of the LoRaWAN metrics in function of the defined range of the target parameter.
#
# The **yaml** file will be used by to Python functions: the **plotScript.py**, which generates all auxiliary files to run simulations; and **plotScript.py**, which plots the simulation results.
#
# Herein, we provide two campaigns we used to perform the proof-of-concept simulations of our ADR proposal. They are:
#
# - **nDevices** campaign with the following parameters:
#    - nDevices (target parameter): 1000, 2000, 3000, 4000, 5000, 6000;
#    - radius: 3000
#
# - **radius** campaign with the following parameters:
#    - radius (target parameter): 2000, 4000, 6000, 8000, 10000;
#    - nDevices: 3000
#
# **Attention**: maybe you need to specify the **ns3_path** (with our complete path) to run simulation in our local machine.

# %% [markdown]
# ### Campaign Criation
#
# To configure the simulation campaign and create **ADR_campaign.yaml** file, run the following code. We set a number of 20 simulation runs to get statiscal confidence of performance metrics.

# %%
# %%file ADR_campaign.yaml
# scenario:
#     # Output filename
#     filename: CampaignLoraWAN
#     # Set location of simulation: local or cluster
#     simLocation: local
#     # Set campaign scenario: a name of one valid parameter
#     #campaign: radius
#     campaign:
#         - radius
#         - nDevices
#     # Number of jobs to run
#     jobs: 20
#     # Simulation duration (seconds)
#     simulationTime: 600
#     # Number of end devices to include in the simulation
#     nDevices:
#         - 3000
#         - 1000
#         - 2000
#         - 4000
#         - 5000
#         - 6000
#     # The radius of the area to simulate
#     radius:
#         - 3000
#         - 2000
#         - 4000
#         - 6000
#         - 8000
#         - 10000
#     # The period in seconds to be used by periodically transmitting applications
#     appPeriodSeconds: 600
#     # Whether or not to print various informations
#     bPrint: false
#     # Fixed seed and run seed (set false for a long simulation campaign)
#     fixedSeed: false
#     # Algoritmo de ADR: 1 to 5
#     Algoritmo:
#         - 1
#         - 2
#         - 3
#         - 4
#         - 5
#     # Complete path of ns-3 simulator
#     ns3_path: ns-allinone-3.29/ns-3.29
#     # Script with the main code (inside scratch folder without .cc)
#     ns3_script: ADR_code
# Out:
# Overwriting ADR_campaign.yaml

# %% [markdown]
# A seguinte função em python foi criada para, de posse do arquivo **yaml**, criar um arquivo **.sh** para rodar a campanha de simulação.  Ao executar esse código no Jupyter Notebook (Shift+Enter), o arquivo **loraScript.py** é gerado.

# %%
# %%file loraScript.py
from collections import defaultdict
import os
import math
import random
import re
import subprocess
import sys
import argparse
from glob import glob
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
# To install YAML: sudo apt-get install python3-yaml
import yaml

class Simulation:
    def __init__(self, configurations_file):
        #self.email_to = 'sicrano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.campaign = self.doc['scenario']['campaign']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.simulationTime = self.doc['scenario']['simulationTime']
        self.nDevices = self.doc['scenario']['nDevices'][0]
        self.radius = self.doc['scenario']['radius'][0]
        self.appPeriodSeconds = self.doc['scenario']['appPeriodSeconds']
        self.bPrint = (self.doc['scenario']['bPrint'])
        self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.algoritmo = self.doc['scenario']['Algoritmo']
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        self.filename = str(self.doc['scenario']['filename'])
        self.configurations_file = configurations_file
       
    def runCampaign(self,curCampaign):
        # Configure simulation file in accordance with campaign parameter
        sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign
        print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
        with open('run_%s.sh' % sh_name, 'w') as f:                    
            if self.simLocation == 'cluster':
              print('To be implemented')
            else:
              outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign
              f.write('#!/bin/bash\n')
              f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
              f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
              f.write("cd '"+self.ns3_path+"'"+"\n")
              f.write('rm -rf '+outputDir+' 2>/dev/null\n')
              f.write('mkdir -p '+outputDir+'\n')
            for iJob in range(0, self.nJobs):
                jobRunSeed = random.randint(1, 23*10**14)
                for iAlg in self.algoritmo:                           
                    for varParam in self.doc['scenario'][curCampaign]:
                      if str(curCampaign) == 'radius':
                          command = (
                          'NS_GLOBAL_VALUE="RngRun='+str(jobRunSeed)+ '" ' +
                          "./waf --run '"+self.ns3_script+
                          " --radius="+varParam+
                          " --nDevices="+self.nDevices+
                          " --simulationTime="+self.simulationTime+
                          " --appPeriodSeconds="+self.appPeriodSeconds+
                          " --print="+self.bPrint+
                          " --fixedSeed="+str(self.fixedSeed)+
                          " --algoritmo="+iAlg+
                          " --filename="+ self.filename +
                          " --outputDir='"+outputDir+"'"
                          "'"
                          )
                      elif str(curCampaign) == 'nDevices':
                          command = (
                          'NS_GLOBAL_VALUE="RngRun='+str(jobRunSeed)+ '" ' +
                          "./waf --run '"+self.ns3_script+ 
                          " --radius="+self.radius+
                          " --nDevices="+varParam+
                          " --simulationTime="+self.simulationTime+
                          " --appPeriodSeconds="+self.appPeriodSeconds+
                          " --print="+self.bPrint+
                          " --fixedSeed="+str(self.fixedSeed)+
                          " --algoritmo="+iAlg+
                          " --filename="+ self.filename +
                          " --outputDir='"+outputDir+"'"
                          "'"
                          )
                      f.write(command+' & wait\n')
                      
parser = argparse.ArgumentParser()
parser.add_argument("-f", "--file", type=str, help='Configuration File')
args = parser.parse_args()

configurations_file = args.file; 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]

print('Simulação escolhida: ')
campaign = doc['scenario']['campaign']
print(campaign)
                 
simu = Simulation(configurations_file)

for simC in campaign:
    if str(simC) == 'nDevices' or str(simC) == 'radius':
        simu.runCampaign(simC);
    else:
        print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting loraScript.py

# %% [markdown]
# O Script **loraScript.py** recebe um arquivo **yaml** com parâmetro de entrada e gera os segugintes arquivos:
#
# - **run_campanha_local_nDevices.sh**: com as chamadas para as simulações variando o número de dispositivos;
# - **run_campanha_local_radius.sh**: com as chamadas para as simulações variando o raio.
#
# Esses dois arquivos **.sh** devem ser chamados em um terminal, chamando as simulações especificas de cada caso.
#
# Abaixo, o script **loraScript.py** é chamado para a **campanha_1.yaml** criada anteriormente.

# %%
# %run loraScript -f "ADR_campaign.yaml"
# Out:
# Simulação escolhida:
# ['radius', 'nDevices']
# radius campaign written in file: run_ADR_campaign_local_radius.sh
# nDevices campaign written in file: run_ADR_campaign_local_nDevices.sh

# %% [markdown]
# Para rodar o código em um terminal, digite:
#
# ```python
# python3 loraScript.py -f 'ADR_campaign.yaml'
# ```

# %% [markdown]
# Ao rodar o **loraScript.py** com o arquivo **campanha_1.yaml** como parâmetro, os arquivos  **run_all_campanha_1_local_nDevices.sh** e **run_all_campanha_1_local_radius.sh** foram criados. Eles contém a chamada de código para as duas campanhas de simulação especificadas em **campanha_1.yaml**.
#
# O código a seguir executa os dois arquivos **.sh** diretamente deste Jupyter Notebook.

# %%
# !chmod +x ./run_ADR_campaign_local_radius.sh
# !./run_ADR_campaign_local_radius.sh


# !chmod +x ./run_ADR_campaign_local_nDevices.sh
# !./run_ADR_campaign_local_nDevices.sh
# Out:
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.806s)
# simulation start at: Wed Feb 19 09:58:18 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 09:59:59 2020
#
# Time elapsed: 1.68333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.902s)
# simulation start at: Wed Feb 19 10:00:01 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:01:51 2020
#
# Time elapsed: 1.83333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.788s)
# simulation start at: Wed Feb 19 10:01:53 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:03:41 2020
#
# Time elapsed: 1.8 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.863s)
# simulation start at: Wed Feb 19 10:03:43 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:05:30 2020
#
# Time elapsed: 1.78333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.794s)
# simulation start at: Wed Feb 19 10:05:32 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:07:18 2020
#
# Time elapsed: 1.76667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.870s)
# simulation start at: Wed Feb 19 10:07:20 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:09:04 2020
#
# Time elapsed: 1.73333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.781s)
# simulation start at: Wed Feb 19 10:09:06 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:10:52 2020
#
# Time elapsed: 1.76667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.879s)
# simulation start at: Wed Feb 19 10:10:54 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:12:42 2020
#
# Time elapsed: 1.8 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.873s)
# simulation start at: Wed Feb 19 10:12:44 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:14:31 2020
#
# Time elapsed: 1.78333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.809s)
# simulation start at: Wed Feb 19 10:14:33 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:16:17 2020
#
# Time elapsed: 1.73333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.804s)
# simulation start at: Wed Feb 19 10:16:19 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:18:00 2020
#
# Time elapsed: 1.68333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.786s)
# simulation start at: Wed Feb 19 10:18:03 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:19:46 2020
#
# Time elapsed: 1.71667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.785s)
# simulation start at: Wed Feb 19 10:19:48 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:21:35 2020
#
# Time elapsed: 1.78333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.786s)
# simulation start at: Wed Feb 19 10:21:37 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:23:28 2020
#
# Time elapsed: 1.85 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.745s)
# simulation start at: Wed Feb 19 10:23:30 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:25:16 2020
#
# Time elapsed: 1.76667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.788s)
# simulation start at: Wed Feb 19 10:25:18 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:27:03 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.798s)
# simulation start at: Wed Feb 19 10:27:05 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:28:50 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.788s)
# simulation start at: Wed Feb 19 10:28:53 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:30:39 2020
#
# Time elapsed: 1.76667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.777s)
# simulation start at: Wed Feb 19 10:30:41 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:32:26 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.796s)
# simulation start at: Wed Feb 19 10:32:28 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:34:13 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.781s)
# simulation start at: Wed Feb 19 10:34:15 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:35:59 2020
#
# Time elapsed: 1.73333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.803s)
# simulation start at: Wed Feb 19 10:36:01 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:37:45 2020
#
# Time elapsed: 1.73333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.786s)
# simulation start at: Wed Feb 19 10:37:47 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:39:32 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.860s)
# simulation start at: Wed Feb 19 10:39:34 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:41:15 2020
#
# Time elapsed: 1.68333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.786s)
# simulation start at: Wed Feb 19 10:41:17 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:42:59 2020
#
# Time elapsed: 1.7 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.789s)
# simulation start at: Wed Feb 19 10:43:01 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:44:41 2020
#
# Time elapsed: 1.66667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.792s)
# simulation start at: Wed Feb 19 10:44:43 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:46:23 2020
#
# Time elapsed: 1.66667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.765s)
# simulation start at: Wed Feb 19 10:46:25 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:48:08 2020
#
# Time elapsed: 1.71667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.785s)
# simulation start at: Wed Feb 19 10:48:10 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:49:51 2020
#
# Time elapsed: 1.68333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.770s)
# simulation start at: Wed Feb 19 10:49:53 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4116868799, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:51:33 2020
#
# Time elapsed: 1.66667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.823s)
# simulation start at: Wed Feb 19 10:51:35 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:53:16 2020
#
# Time elapsed: 1.68333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.791s)
# simulation start at: Wed Feb 19 10:53:18 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:54:52 2020
#
# Time elapsed: 1.56667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.802s)
# simulation start at: Wed Feb 19 10:54:54 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:56:33 2020
#
# Time elapsed: 1.65 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.776s)
# simulation start at: Wed Feb 19 10:56:35 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 10:58:20 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.791s)
# simulation start at: Wed Feb 19 10:58:22 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:00:01 2020
#
# Time elapsed: 1.65 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.783s)
# simulation start at: Wed Feb 19 11:00:03 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:01:40 2020
#
# Time elapsed: 1.61667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.781s)
# simulation start at: Wed Feb 19 11:01:42 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:03:22 2020
#
# Time elapsed: 1.66667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.771s)
# simulation start at: Wed Feb 19 11:03:24 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:05:02 2020
#
# Time elapsed: 1.63333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.769s)
# simulation start at: Wed Feb 19 11:05:04 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:06:46 2020
#
# Time elapsed: 1.7 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.786s)
# simulation start at: Wed Feb 19 11:06:48 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:08:32 2020
#
# Time elapsed: 1.73333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.775s)
# simulation start at: Wed Feb 19 11:08:34 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:10:16 2020
#
# Time elapsed: 1.7 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.820s)
# simulation start at: Wed Feb 19 11:10:18 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:11:57 2020
#
# Time elapsed: 1.65 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.830s)
# simulation start at: Wed Feb 19 11:11:59 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:13:37 2020
#
# Time elapsed: 1.63333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.765s)
# simulation start at: Wed Feb 19 11:13:39 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:15:16 2020
#
# Time elapsed: 1.61667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.760s)
# simulation start at: Wed Feb 19 11:15:18 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:17:00 2020
#
# Time elapsed: 1.7 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.863s)
# simulation start at: Wed Feb 19 11:17:02 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:18:47 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.769s)
# simulation start at: Wed Feb 19 11:18:49 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:20:28 2020
#
# Time elapsed: 1.65 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.801s)
# simulation start at: Wed Feb 19 11:20:30 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:22:07 2020
#
# Time elapsed: 1.61667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.762s)
# simulation start at: Wed Feb 19 11:22:09 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:23:47 2020
#
# Time elapsed: 1.63333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.777s)
# simulation start at: Wed Feb 19 11:23:49 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:25:29 2020
#
# Time elapsed: 1.66667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.784s)
# simulation start at: Wed Feb 19 11:25:31 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:27:14 2020
#
# Time elapsed: 1.71667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.800s)
# simulation start at: Wed Feb 19 11:27:16 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:28:58 2020
#
# Time elapsed: 1.7 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.770s)
# simulation start at: Wed Feb 19 11:29:00 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:30:45 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.747s)
# simulation start at: Wed Feb 19 11:30:47 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:32:34 2020
#
# Time elapsed: 1.78333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.789s)
# simulation start at: Wed Feb 19 11:32:36 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:34:21 2020
#
# Time elapsed: 1.75 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.766s)
# simulation start at: Wed Feb 19 11:34:23 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:36:07 2020
#
# Time elapsed: 1.73333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.813s)
# simulation start at: Wed Feb 19 11:36:09 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:37:55 2020
#
# Time elapsed: 1.76667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.776s)
# simulation start at: Wed Feb 19 11:37:57 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:39:33 2020
#
# Time elapsed: 1.6 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.801s)
# simulation start at: Wed Feb 19 11:39:35 2020
#
# Running with nDevices = 3000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:41:14 2020
#
# Time elapsed: 1.65 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.762s)
# simulation start at: Wed Feb 19 11:41:16 2020
#
# Running with nDevices = 3000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1210512250, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:42:54 2020
#
# Time elapsed: 1.63333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.809s)
# simulation start at: Wed Feb 19 11:42:56 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3985746143, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:44:34 2020
#
# Time elapsed: 1.63333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.776s)
# simulation start at: Wed Feb 19 11:44:36 2020
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3985746143, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:46:08 2020
#
# Time elapsed: 1.53333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.726s)
# simulation start at: Wed Feb 19 11:46:10 2020
#
# Running with nDevices = 3000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3985746143, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:47:35 2020
#
# Time elapsed: 1.41667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.724s)
# simulation start at: Wed Feb 19 11:47:37 2020
#
# Running with nDevices = 3000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3985746143, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Wed Feb 19 11:49:00 2020
#
# Time elapsed: 1.38333 minutes
# ...
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:33:33 2020
#
# Time elapsed: 0.55 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.744s)
# simulation start at: Fri Feb 21 04:33:35 2020
#
# Running with nDevices = 4000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:36:34 2020
#
# Time elapsed: 2.98333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.723s)
# simulation start at: Fri Feb 21 04:36:36 2020
#
# Running with nDevices = 5000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:41:25 2020
#
# Time elapsed: 4.81667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.724s)
# simulation start at: Fri Feb 21 04:41:27 2020
#
# Running with nDevices = 6000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:48:15 2020
#
# Time elapsed: 6.8 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.764s)
# simulation start at: Fri Feb 21 04:48:17 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:49:46 2020
#
# Time elapsed: 1.48333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.736s)
# simulation start at: Fri Feb 21 04:49:48 2020
#
# Running with nDevices = 1000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:49:53 2020
#
# Time elapsed: 0.0833333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.735s)
# simulation start at: Fri Feb 21 04:49:55 2020
#
# Running with nDevices = 2000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:50:25 2020
#
# Time elapsed: 0.5 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.729s)
# simulation start at: Fri Feb 21 04:50:27 2020
#
# Running with nDevices = 4000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:53:27 2020
#
# Time elapsed: 3 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.728s)
# simulation start at: Fri Feb 21 04:53:29 2020
#
# Running with nDevices = 5000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 04:58:27 2020
#
# Time elapsed: 4.96667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.730s)
# simulation start at: Fri Feb 21 04:58:29 2020
#
# Running with nDevices = 6000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:05:46 2020
#
# Time elapsed: 7.28333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.725s)
# simulation start at: Fri Feb 21 05:05:48 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:07:17 2020
#
# Time elapsed: 1.48333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.741s)
# simulation start at: Fri Feb 21 05:07:19 2020
#
# Running with nDevices = 1000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:07:24 2020
#
# Time elapsed: 0.0833333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.747s)
# simulation start at: Fri Feb 21 05:07:26 2020
#
# Running with nDevices = 2000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:08:01 2020
#
# Time elapsed: 0.583333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.723s)
# simulation start at: Fri Feb 21 05:08:03 2020
#
# Running with nDevices = 4000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:11:05 2020
#
# Time elapsed: 3.03333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.737s)
# simulation start at: Fri Feb 21 05:11:07 2020
#
# Running with nDevices = 5000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:16:02 2020
#
# Time elapsed: 4.91667 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.728s)
# simulation start at: Fri Feb 21 05:16:04 2020
#
# Running with nDevices = 6000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:23:16 2020
#
# Time elapsed: 7.2 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.726s)
# simulation start at: Fri Feb 21 05:23:18 2020
#
# Running with nDevices = 3000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:24:47 2020
#
# Time elapsed: 1.48333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.730s)
# simulation start at: Fri Feb 21 05:24:49 2020
#
# Running with nDevices = 1000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:24:54 2020
#
# Time elapsed: 0.0833333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.750s)
# simulation start at: Fri Feb 21 05:24:56 2020
#
# Running with nDevices = 2000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:25:29 2020
#
# Time elapsed: 0.55 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.763s)
# simulation start at: Fri Feb 21 05:25:31 2020
#
# Running with nDevices = 4000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:28:21 2020
#
# Time elapsed: 2.83333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.752s)
# simulation start at: Fri Feb 21 05:28:23 2020
#
# Running with nDevices = 5000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:33:16 2020
#
# Time elapsed: 4.88333 minutes
# Waf: Entering directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (1.740s)
# simulation start at: Fri Feb 21 05:33:18 2020
#
# Running with nDevices = 6000, radius = 3000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 1819121659, outputDir = /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Feb 21 05:41:01 2020
#
# Time elapsed: 7.71667 minutes

# %% [markdown]
# Os arquivos **.sh** acima chamam as simulações uma a uma, guardando o resultados no seguintes arquivos e pastas:
#
# - **./ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices**: para simulações variando o parâmetros **nDevices**;
#     - **campanha_1_local_nDevices.txt**: para resultados de simulação do arquivo **campanha_1.yaml**;
#     - **campanha_2_local_nDevices.txt**: para resultados de simulação do arquivo **campanha_2.yaml**;
#
#
# - **./ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius**: para simulações variando o parâmetros **radius**;
#     - **campanha_1_local_radius.txt**: para resultados de simulação do arquivo **campanha_1.yaml**;
#     - **campanha_2_local_radius.txt**: para resultados de simulação do arquivo **campanha_2.yaml**;

# %% [markdown]
# Abaixo, o script **loraScript.py** é chamado para criar a outra campanha de simulações criada anteriormente (**campanha_2.yaml**).

# %% [markdown]
# # Plotar gráficos
#
# Para plotar gráficos, chamaremos o mesmo arquivo **yaml** que foi usado para criar as campanhas de simulação. Um novo script chamado **plotScript.py** foi construído para esse fim. Ao executar esse código no Jupyter Notebook (Shift+Enter), o arquivo **plotScript.py** é gerado.

# %%
# %%file plotScript.py
# Legend
#   RunSeed: 0
#   Seed: 1
#   Algoritmo: 2
#   Radius: 3
#   nDevices: 4
#   appPeriodSeconds:5
#   simulationTime:6
#   PHYTotal: 7
#   PHYSuccessful:8 
#   PHYInterfered: 9
#   PHYNoMoreReceivers: 10
#   PHYUnderSensitivity: 11
#   PHYLostBecauseTX: 12
#   SimulationDuration: 13

import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
import scipy.stats as st
import os
import argparse
import yaml
import matplotlib

class openSimulation:
    def __init__(self, configurations_file):
        self.email_to = 'fulano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.showPlot = True;
        self.plotCI = True;                
        self.campaign = self.doc['scenario']['campaign']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.simulationTime = self.doc['scenario']['simulationTime']
        self.nDevices = self.doc['scenario']['nDevices']
        self.nDevices = list(map(float,self.nDevices))
        self.radius = self.doc['scenario']['radius']
        self.radius = list(map(float,self.radius))
        self.appPeriodSeconds = self.doc['scenario']['appPeriodSeconds']
        self.bPrint = (self.doc['scenario']['bPrint'])
        self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.algoritmo = self.doc['scenario']['Algoritmo']
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        if self.nJobs == 1: # disable the confidence interval
            self.plotCI = False;
        self.filename = str(self.doc['scenario']['filename'])
        
    def doLabel(self, algID):
        # Define labels for plots legends
        if algID == '1':
            return "SF7 (I)"
        elif algID == '2':
            return "Equal Split (II)"
        elif algID == '3':
            return "Unequal Split (III)"
        elif algID == '4':
            return "Product-based (IV)"
        elif algID == '5':
            return "Proposed ADR (V)"
        
        
    def plotCampaign(self,curCampaign, metric):
        # some general configurations
        outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign        
        chFile = outputDir+ "/" + self.filename + '.txt'        
        print(chFile)
        simTime = np.loadtxt(chFile, skiprows=1, usecols=(6, ), delimiter=',', unpack=False)                
        resalg = np.loadtxt(chFile, skiprows=1, usecols=(2, ), delimiter=',', unpack=False)
        resradius = np.loadtxt(chFile, skiprows=1, usecols=(3, ), delimiter=',', unpack=False)
        resnDevices = np.loadtxt(chFile, skiprows=1, usecols=(4, ), delimiter=',', unpack=False)
        ressimDur = np.loadtxt(chFile, skiprows=1, usecols=(13, ), delimiter=',', unpack=False)
        resphyTotal = np.loadtxt(chFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
        resphySucc = np.loadtxt(chFile, skiprows=1, usecols=(8, ), delimiter=',', unpack=False)
            
        markersA = cycle(('o', 'v', '^', 's', '>', 'p', '*', 'h', '<', 'H', 'D', 'd'))
        colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))                    
        plt.figure()     
        for iAlg in self.algoritmo:
            m_plr, m_plrCI, m_tput, m_tputCI, m_pkt, m_pktCI = [], [], [], [], [], []
            for varParam in sorted(self.doc['scenario'][curCampaign],key=int):
                                
                if str(curCampaign) == 'radius':
                    resalgIndexs = (resalg == int(iAlg)) & (resradius == int(varParam))
                    xlabel='Distância [m]'
                    resxData = sorted(self.radius,key=int)
                elif str(curCampaign) == 'nDevices':
                    resalgIndexs = (resalg == int(iAlg)) & (resnDevices == int(varParam))                    
                    xlabel='Quantidade de Dispositivos'
                    resxData = sorted(self.nDevices,key=int)
                # Plr Evaluation
                label = self.doLabel(iAlg)
                #print(label)
                color=next(colors)
                marker=next(markersA)
                if metric=='PLR':                
                    # Calculate PLR line
                    plr = 100*( resphyTotal[resalgIndexs]-resphySucc[resalgIndexs] ) / resphyTotal[resalgIndexs]
                    m_plr = np.append(m_plr, np.mean(plr))
                    # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                    l, h = st.t.interval(0.95, len(plr)-1, loc=np.mean(plr), scale=st.sem(plr))
                    #l,h = st.norm.interval(0.95, loc=np.mean(plr), scale=st.sem(plr))                                                            
                    m_plrCI = np.append(m_plrCI, h)
                elif metric=='Tput':
                    # TODO
                    # Calculate PLR line
                    tput = 23*( resphySucc[resalgIndexs] ) / float(self.simulationTime)
                    m_tput = np.append(m_tput, np.mean(tput))
                    # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                    l, h = st.t.interval(0.95, len(tput)-1, loc=np.mean(tput), scale=st.sem(tput))
                    #l,h = st.norm.interval(0.95, loc=np.mean(tput), scale=st.sem(tput))                    
                    m_tputCI = np.append(m_tputCI, h)
                elif metric=='Pkt':
                    # TODO
                    # Calculate PLR line
                    pkt = 100 * ( resphySucc[resalgIndexs] ) / resphyTotal[resalgIndexs]
                    m_pkt = np.append(m_pkt, np.mean(pkt))
                    # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                    l, h = st.t.interval(0.95, len(pkt)-1, loc=np.mean(pkt), scale=st.sem(pkt))
                    #l,h = st.norm.interval(0.95, loc=np.mean(pkt), scale=st.sem(pkt))                    
                    m_pktCI = np.append(m_pktCI, h)

                
            # Plot line
            if metric=='PLR':                         
                plt.plot(resxData,m_plr, label=label, marker=marker,color=color)   
                if bool(self.plotCI):
                    plt.errorbar(resxData,m_plr, yerr=(m_plrCI-m_plr), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2)
            elif metric=='Tput':
                # TODO
                plt.plot(resxData,m_tput, label=label, marker=marker,color=color)    
                if bool(self.plotCI):                
                    plt.errorbar(resxData,m_tput, yerr = (m_tputCI-m_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2)
            elif metric=='Pkt':
                # TODO
                plt.plot(resxData,m_pkt, label=label, marker=marker,color=color)    
                if bool(self.plotCI):                
                    plt.errorbar(resxData,m_pkt, yerr = (m_pktCI-m_pkt), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2)
            
        # Plot figure
        params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
        plt.rcParams.update(params)        
        os.makedirs(outputDir+"/ps", exist_ok=True)
        os.makedirs(outputDir+"/png", exist_ok=True)
        
        if metric=='PLR':        
            # Show and save PLR plot
            ylabel="PLR [%]"
            plt.xlabel(xlabel)
            plt.ylabel(ylabel)
            plt.legend(loc='best', numpoints=1)        
            plt.grid()
            plt.tight_layout()
            if bool(self.plotCI):
                imgfilename = 'PLR_CI_'+curCampaign
            else:
                imgfilename = 'PLR_'+curCampaign
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()
                
        elif metric=='Tput':
            # TODO
            # Show and save PLR plot
            ylabel="Tput [bps]"
            plt.xlabel(xlabel)
            plt.ylabel(ylabel)
            plt.legend(loc='best', numpoints=1)        
            plt.grid()
            plt.tight_layout()
            if bool(self.plotCI):
                imgfilename = 'TPUT_CI_'+curCampaign
            else:
                imgfilename = 'TPUT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()

        elif metric=='Pkt':
            # TODO
            # Show and save PLR plot
            ylabel="Pacotes recebidos [%]"
            plt.xlabel(xlabel)
            plt.ylabel(ylabel)
            #plt.legend(loc='upper left', numpoints=1)        
            plt.legend(loc='best', numpoints=1)        
            plt.grid()
            plt.tight_layout()
            if bool(self.plotCI):
                imgfilename = 'PKT_CI_'+curCampaign
            else:
                imgfilename = 'PKT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()

parser = argparse.ArgumentParser()
parser.add_argument("-f", "--file", type=str, help='Configuration File')
args = parser.parse_args()

configurations_file = args.file; 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]

# print(doc)
print('Simulação escolhida: ')
campaign = doc['scenario']['campaign']
print(campaign)
                 
simu = openSimulation(configurations_file)
for iMet in ['PLR', 'Tput', 'Pkt']:
    for simC in campaign:
        if str(simC) == 'nDevices' or str(simC) == 'radius':
            simu.plotCampaign(simC,iMet);
        else:
            print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting plotScript.py

# %% [markdown]
# Abaixo, o script **plotScript.py** é chamado para a **campanha_1.yaml** criada e simulada anteriormente.

# %%
# %run plotScript -f "ADR_campaign.yaml"
# Out:
# Simulação escolhida:
# ['radius', 'nDevices']
# /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/CampaignLoraWAN.txt
# /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/CampaignLoraWAN.txt
# /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/CampaignLoraWAN.txt
# /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/CampaignLoraWAN.txt
# /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/CampaignLoraWAN.txt
# /home/simulacao/vicente/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/CampaignLoraWAN.txt

# %% [markdown]
# É possível abservar que o intervalo de confiana já é bem pequeno para 20 jobs.
