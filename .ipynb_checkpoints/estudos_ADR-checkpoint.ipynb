# %% [markdown]
# # Estudos ADR
#
# ## Pesquisadores: Luiz (UFJF), Álvaro (UFJF), Jessika (UFRN), Vicente Sousa (UFRN)
#
# **Objetivos:**
#
# - Analisar mudanças realizadas pelo grupo UFJF para implmentação de algoritmos de ADR;
# - Criar path do código;
# - Criar script para criar campanhas de simulação;
# - Criar script para plotar campanha de simulação;
# - Analisar novos resultados e comparar com os produzidos anteriormente.

# %% [markdown]
# # Processo de instalação
#
# A instalação depende de três etapas:
# - Baixar e instalar dependências;
# - Baixar o repositório do código mais atual do ns-3 (ns-3.29);
# - Baixar o repositório do código do LoRa (módulo em **https://github.com/signetlabdei/lorawan**) e mesclar com o código ns-3.29;
# - Incorporar mudanças do Luiz Quirino (UFJF) com implementações de novos algoritmos de ADR (o código está na pasta **LoRa-Luiz-vicente**).
#
# O script **ns3_full_installation.sh** foi construído para realizar as quatro etapas acima. Ele deve ser chamado da pasta do repositório do ns-3-lora-gppcom. Esse script já foi executado na pasta e o conteúdo gerado foi incorporado no repositório, objetivando tornar as demais etapas executáveis neste documento.
#
# Contudo, para não guardar todo o código compilado, você baixar o repositório, configurar e compilar o código.
#
# - Para baixar o repositório, digite em um terminal:
#
# ```bash
# git clone https://github.com/vicentesousa/ns-3-lora-gppcom.git
# ```
#
# - Para entrar na pasta:
#
# ```bash
# cd ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/
# ```
# - Configurar:
#
# ```bash
# CXXFLAGS="-Wall -g -O0" ./waf --build-profile=debug --disable-examples --disable-tests --disable-python configure
# ```
#
# - Compilar:
#
# ```bash
# ./waf
# ```

# %% [markdown]
# # Processo de criação de campanha de simulação
#
# Os processos de criação de uma campanha de simulação e de geração de gráficos estão vinculados a um arquivo de extensão **yaml**. Nele, a variação de parâmetros da camapanha de simulação é definido e será usado por duas função em python: uma que gerará a campanha de simulação (**plotScript.py**) e outro que plotará os gráficos (**plotScript.py**).
#
# A seguir é mostrado um exemplo do arquivo **yaml** de configuração da campanha de simulação. Ao executar esse código no Jupyter Notebook (Shift+Enter), o arquivo **campanha_1.yaml** é gerado.
#
# Esse código especifica (não gera ainda) uma camapanha de simulação com os parâmetros **radius** (2000, 4000, 6000, 8000, 10000) e **nDevices** (1000, 2000, 3000, 4000, 5000, 6000) para os valores do parâmetro **Algoritmo** variando de 1 a 5.
#
# **Importante**: para que esse código funcione na sua máquina local, talvez você precise editar o parâmetro **ns3_path**, espeficiando o caminho completo do ns-3.

# %%
# %%file campanha_1.yaml
# scenario:
#     # Output filename
#     filename: DadosLora_1_job
#     # Set location of simulation: local or cluster
#     simLocation: local
#     # Set campaign scenario: a name of one valid parameter
#     #campaign: radius
#     campaign:
#         - radius
#         - nDevices
#     # Number of jobs to run
#     jobs: 1
#     # Simulation duration (seconds)
#     simulationTime: 600
#     # Number of end devices to include in the simulation
#     nDevices:
#         - 1000
#         - 2000
#         - 3000
#         - 4000
#         - 5000
#         - 6000
#     # The radius of the area to simulate
#     radius:
#         - 2000
#         - 4000
#         - 6000
#         - 8000
#         - 10000
#     # The period in seconds to be used by periodically transmitting applications
#     appPeriodSeconds: 600
#     # Whether or not to print various informations
#     bPrint: false
#     # Fixed seed and run seed (set false for a long simulation campaign)
#     fixedSeed: false
#     # Algoritmo de ADR: 1 to 5
#     Algoritmo:
#         - 1
#         - 2
#         - 3
#         - 4
#         - 5
#     # Complete path of ns-3 simulator
#     ns3_path: ns-allinone-3.29/ns-3.29
#     # Script with the main code (inside scratch folder without .cc)
#     ns3_script: ADR_code
# Out:
# Overwriting campanha_1.yaml

# %% [markdown]
# A seguir é criado o arquivo **campanha_2.yaml** para a mesma campanha de simulação, agora com 10 jobs.

# %%
# %%file campanha_2.yaml
# scenario:
#     # Output filename
#     filename: DadosLora_10_jobs
#     # Set location of simulation: local or cluster
#     simLocation: local
#     # Set campaign scenario: a name of one valid parameter
#     #campaign: radius
#     campaign:
#         - radius
#         - nDevices
#     # Number of jobs to run
#     jobs: 10
#     # Simulation duration (seconds)
#     simulationTime: 600
#     # Number of end devices to include in the simulation
#     nDevices:
#         - 1000
#         - 2000
#         - 3000
#         - 4000
#         - 5000
#         - 6000
#     # The radius of the area to simulate
#     radius:
#         - 2000
#         - 4000
#         - 6000
#         - 8000
#         - 10000
#     # The period in seconds to be used by periodically transmitting applications
#     appPeriodSeconds: 600
#     # Whether or not to print various informations
#     bPrint: false
#     # Fixed seed and run seed (set false for a long simulation campaign)
#     fixedSeed: false
#     # Algoritmo de ADR: 1 to 5
#     Algoritmo:
#         - 1
#         - 2
#         - 3
#         - 4
#         - 5
#     # Complete path of ns-3 simulator
#     ns3_path: ns-allinone-3.29/ns-3.29
#     # Script with the main code (inside scratch folder without .cc)
#     ns3_script: ADR_code
# Out:
# Overwriting campanha_2.yaml

# %% [markdown]
# A seguinte função em python foi criada para, de posse do arquivo **yaml**, criar um arquivo **.sh** para rodar a campanha de simulação.  Ao executar esse código no Jupyter Notebook (Shift+Enter), o arquivo **loraScript.py** é gerado.

# %%
# %%file loraScript.py
from collections import defaultdict
import os
import math
import random
import re
import subprocess
import sys
import argparse
from glob import glob
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
# To install YAML: sudo apt-get install python3-yaml
import yaml

class Simulation:
    def __init__(self, configurations_file):
        self.email_to = 'martinsdecastro23@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.campaign = self.doc['scenario']['campaign']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.simulationTime = self.doc['scenario']['simulationTime']
        self.nDevices = self.doc['scenario']['nDevices'][0]
        self.radius = self.doc['scenario']['radius'][0]
        self.appPeriodSeconds = self.doc['scenario']['appPeriodSeconds']
        self.bPrint = (self.doc['scenario']['bPrint'])
        self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.algoritmo = self.doc['scenario']['Algoritmo']
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        self.filename = str(self.doc['scenario']['filename'])
       
    def runCampaign(self,curCampaign):
        # Configure simulation file in accordance with campaign parameter
        sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign
        print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
        with open('run_all_%s.sh' % sh_name, 'w') as f:                    
            if self.simLocation == 'cluster':
              print('To be implemented')
            else:
              f.write('#!/bin/bash\n')
              f.write("cd '"+self.ns3_path+"'"+"\n")
              outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign
              #f.write('rm -rf '+outputDir+' 2>/dev/null\n')
              f.write('mkdir -p '+outputDir+'\n')
            for iJob in range(0, self.nJobs):
                jobRunSeed = random.randint(1, 23*10**14)
                for iAlg in self.algoritmo:                           
                    for varParam in self.doc['scenario'][curCampaign]:
                      if str(curCampaign) == 'radius':
                          command = (
                          'NS_GLOBAL_VALUE="RngRun='+str(jobRunSeed)+ '" ' +
                          "./waf --run '"+self.ns3_script+
                          " --radius="+varParam+
                          " --nDevices="+self.nDevices+
                          " --simulationTime="+self.simulationTime+
                          " --appPeriodSeconds="+self.appPeriodSeconds+
                          " --print="+self.bPrint+
                          " --fixedSeed="+str(self.fixedSeed)+
                          " --algoritmo="+iAlg+
                          " --filename="+ self.filename +
                          " --outputDir='"+outputDir+"'"
                          "'"
                          )
                      elif str(curCampaign) == 'nDevices':
                          command = (
                          'NS_GLOBAL_VALUE="RngRun='+str(jobRunSeed)+ '" ' +
                          "./waf --run '"+self.ns3_script+ 
                          " --radius="+self.radius+
                          " --nDevices="+varParam+
                          " --simulationTime="+self.simulationTime+
                          " --appPeriodSeconds="+self.appPeriodSeconds+
                          " --print="+self.bPrint+
                          " --fixedSeed="+str(self.fixedSeed)+
                          " --algoritmo="+iAlg+
                          " --filename="+ self.filename +
                          " --outputDir='"+outputDir+"'"
                          "'"
                          )
                      f.write(command+' & wait\n')
                      
parser = argparse.ArgumentParser()
parser.add_argument("-f", "--file", type=str, help='Configuration File')
args = parser.parse_args()

configurations_file = args.file; 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]

print('Simulação escolhida: ')
campaign = doc['scenario']['campaign']
print(campaign)
                 
simu = Simulation(configurations_file)

for simC in campaign:
    if str(simC) == 'nDevices' or str(simC) == 'radius':
        simu.runCampaign(simC);
    else:
        print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting loraScript.py

# %% [markdown]
# O Script **loraScript.py** recebe um arquivo **yaml** com parâmetro de entrada e gera os segugintes arquivos:
#
# - **run_campanha_local_nDevices.sh**: com as chamadas para as simulações variando o número de dispositivos;
# - **run_campanha_local_radius.sh**: com as chamadas para as simulações variando o raio.
#
# Esses dois arquivos **.sh** devem ser chamados em um terminal, chamando as simulações especificas de cada caso.
#
# Abaixo, o script **loraScript.py** é chamado para a **campanha_1.yaml** criada anteriormente.

# %%
# %run loraScript -f "campanha_1.yaml"
# Out:
# Simulação escolhida:
# ['radius', 'nDevices']
# radius campaign written in file: run_campanha_1_local_radius.sh
# nDevices campaign written in file: run_campanha_1_local_nDevices.sh

# %% [markdown]
# Para rodar o código em um terminal, digite:
#
# ```python
# python3 loraScript.py -f 'campanha_1.yaml'
# ```

# %% [markdown]
# Ao rodar o **loraScript.py** com o arquivo **campanha_1.yaml** como parâmetro, os arquivos  **run_all_campanha_1_local_nDevices.sh** e **run_all_campanha_1_local_radius.sh** foram criados. Eles contém a chamada de código para as duas campanhas de simulação especificadas em **campanha_1.yaml**.
#
# O código a seguir executa os dois arquivos **.sh** diretamente deste Jupyter Notebook.

# %%
# !chmod +x ./run_all_campanha_1_local_nDevices.sh 
# !./run_all_campanha_1_local_nDevices.sh


# !chmod +x ./run_all_campanha_1_local_radius.sh
# !./run_all_campanha_1_local_radius.sh
# Out:
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# [1105/1944] Compiling src/mobility/model/position-allocator.cc
# [1106/1944] Compiling src/mobility/model/mobility-model.cc
# [1107/1944] Compiling src/mobility/model/geographic-positions.cc
# [1110/1944] Compiling src/mobility/model/constant-position-mobility-model.cc
# [1116/1944] Compiling src/mobility/model/constant-velocity-mobility-model.cc
# [1117/1944] Compiling src/mobility/model/random-direction-2d-mobility-model.cc
# [1118/1944] Compiling src/mobility/model/rectangle.cc
# [1119/1944] Compiling src/mobility/model/waypoint.cc
# [1120/1944] Compiling src/mobility/model/constant-velocity-helper.cc
# [1121/1944] Compiling src/mobility/helper/mobility-helper.cc
# [1122/1944] Compiling src/mobility/helper/ns2-mobility-helper.cc
# [1123/1944] Compiling src/mpi/model/remote-channel-bundle.cc
# [1124/1944] Compiling src/mpi/model/remote-channel-bundle-manager.cc
# [1125/1944] Compiling src/mpi/model/mpi-interface.cc
# [1126/1944] Compiling src/mpi/model/distributed-simulator-impl.cc
# [1127/1944] Compiling src/mpi/model/granted-time-window-mpi-interface.cc
# [1128/1944] Compiling src/mpi/model/mpi-receiver.cc
# [1129/1944] Compiling src/mpi/model/null-message-simulator-impl.cc
# [1130/1944] Linking build/lib/libns3.29-mobility-debug.so
# [1131/1944] Compiling src/mpi/model/null-message-mpi-interface.cc
# [1132/1944] Compiling src/bridge/model/bridge-channel.cc
# [1133/1944] Compiling src/bridge/model/bridge-net-device.cc
# ^C
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# [1105/1944] Compiling src/mobility/model/position-allocator.cc
# [1106/1944] Compiling src/mobility/model/random-direction-2d-mobility-model.cc
# [1108/1944] Compiling src/mobility/model/geographic-positions.cc
# [1109/1944] Compiling src/mobility/model/constant-velocity-helper.cc
# [1116/1944] Compiling src/mobility/model/constant-velocity-mobility-model.cc
# [1117/1944] Compiling src/mobility/model/mobility-model.cc
# [1118/1944] Compiling src/mobility/model/waypoint.cc
# [1119/1944] Compiling src/mobility/model/rectangle.cc
# [1120/1944] Compiling src/mobility/model/constant-position-mobility-model.cc
# [1121/1944] Compiling src/mobility/helper/mobility-helper.cc
# [1122/1944] Compiling src/mobility/helper/ns2-mobility-helper.cc
# [1123/1944] Compiling src/mpi/model/mpi-interface.cc
# [1124/1944] Compiling src/mpi/model/remote-channel-bundle-manager.cc
# [1125/1944] Compiling src/mpi/model/remote-channel-bundle.cc
# [1126/1944] Compiling src/mpi/model/null-message-mpi-interface.cc
# [1127/1944] Compiling src/mpi/model/granted-time-window-mpi-interface.cc
# [1128/1944] Compiling src/mpi/model/distributed-simulator-impl.cc
# [1129/1944] Compiling src/mpi/model/mpi-receiver.cc
# [1130/1944] Linking build/lib/libns3.29-mobility-debug.so
# [1131/1944] Compiling src/mpi/model/null-message-simulator-impl.cc
# [1132/1944] Compiling src/bridge/model/bridge-net-device.cc
# [1133/1944] Compiling src/bridge/helper/bridge-helper.cc
# [1134/1944] Compiling src/bridge/model/bridge-channel.cc
# [1135/1944] Compiling src/traffic-control/helper/traffic-control-helper.cc
# [1136/1944] Compiling src/traffic-control/model/packet-filter.cc
# [1137/1944] Compiling src/traffic-control/model/fq-codel-queue-disc.cc
# [1138/1944] Linking build/lib/libns3.29-mpi-debug.so
# [1139/1944] Linking build/lib/libns3.29-bridge-debug.so
# [1140/1944] Compiling src/traffic-control/model/prio-queue-disc.cc
# [1141/1944] Compiling src/traffic-control/model/tbf-queue-disc.cc
# [1142/1944] Compiling src/traffic-control/helper/queue-disc-container.cc
# [1143/1944] Compiling src/traffic-control/model/traffic-control-layer.cc
# [1144/1944] Compiling src/traffic-control/model/queue-disc.cc
# [1145/1944] Compiling src/traffic-control/model/fifo-queue-disc.cc
# [1146/1944] Compiling src/traffic-control/model/codel-queue-disc.cc
# [1147/1944] Compiling src/traffic-control/model/mq-queue-disc.cc
# [1148/1944] Compiling src/traffic-control/model/pie-queue-disc.cc
# [1149/1944] Compiling src/traffic-control/model/pfifo-fast-queue-disc.cc
# [1150/1944] Compiling src/traffic-control/model/red-queue-disc.cc
# [1151/1944] Compiling src/propagation/model/kun-2600-mhz-propagation-loss-model.cc
# [1152/1944] Compiling src/propagation/model/itu-r-1411-los-propagation-loss-model.cc
# [1153/1944] Compiling src/propagation/model/cost231-propagation-loss-model.cc
# [1154/1944] Compiling src/propagation/model/itu-r-1411-nlos-over-rooftop-propagation-loss-model.cc
# [1155/1944] Compiling src/propagation/model/okumura-hata-propagation-loss-model.cc
# [1156/1944] Compiling src/propagation/model/propagation-loss-model.cc
# [1157/1944] Compiling src/propagation/model/jakes-propagation-loss-model.cc
# [1158/1944] Linking build/lib/libns3.29-traffic-control-debug.so
# [1159/1944] Compiling src/propagation/model/jakes-process.cc
# [1160/1944] Compiling src/propagation/model/propagation-delay-model.cc
# [1161/1944] Compiling src/antenna/model/parabolic-antenna-model.cc
# [1162/1944] Compiling src/antenna/model/angles.cc
# [1163/1944] Compiling src/antenna/model/cosine-antenna-model.cc
# [1164/1944] Compiling src/antenna/model/antenna-model.cc
# [1165/1944] Linking build/lib/libns3.29-propagation-debug.so
# lib/libns3.29-mobility-debug.so: file not recognized: File truncated
# collect2: error: ld returned 1 exit status
#
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build failed
#  -> task in 'ns3-propagation' failed with exit status 1 (run with -v to display more information)
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# [1161/1944] Linking build/lib/libns3.29-propagation-debug.so
# [1166/1944] Compiling src/antenna/model/isotropic-antenna-model.cc
# [1167/1944] Compiling src/internet/model/ipv4-header.cc
# [1168/1944] Compiling src/internet/model/ipv6-end-point-demux.cc
# [1169/1944] Compiling src/internet/model/arp-queue-disc-item.cc
# [1170/1944] Compiling src/internet/model/ipv6-end-point.cc
# [1171/1944] Linking build/lib/libns3.29-antenna-debug.so
# [1172/1944] Compiling src/internet/model/ipv4-interface-address.cc
# [1173/1944] Compiling src/internet/model/tcp-option.cc
# [1174/1944] Compiling src/internet/model/ipv6-interface.cc
# [1175/1944] Compiling src/internet/model/ipv6-packet-info-tag.cc
# [1176/1944] Compiling src/internet/model/tcp-tx-buffer.cc
# [1177/1944] Compiling src/internet/model/tcp-lp.cc
# [1178/1944] Compiling src/internet/model/tcp-ledbat.cc
# [1179/1944] Compiling src/internet/model/tcp-htcp.cc
# [1180/1944] Compiling src/internet/model/tcp-illinois.cc
# [1181/1944] Compiling src/internet/model/arp-cache.cc
# [1182/1944] Compiling src/internet/model/tcp-yeah.cc
# [1183/1944] Compiling src/internet/model/tcp-bic.cc
# [1184/1944] Compiling src/internet/model/tcp-scalable.cc
# [1185/1944] Compiling src/internet/model/ndisc-cache.cc
# [1186/1944] Compiling src/internet/model/tcp-veno.cc
# [1187/1944] Compiling src/internet/model/tcp-vegas.cc
# [1188/1944] Compiling src/internet/model/tcp-congestion-ops.cc
# [1189/1944] Compiling src/internet/model/tcp-westwood.cc
# [1190/1944] Compiling src/internet/model/tcp-highspeed.cc
# [1191/1944] Compiling src/internet/model/tcp-header.cc
# [1192/1944] Compiling src/internet/model/tcp-socket-state.cc
# [1193/1944] Compiling src/internet/model/tcp-hybla.cc
# [1194/1944] Compiling src/internet/model/tcp-socket-base.cc
# [1195/1944] Compiling src/internet/model/ipv6-option-demux.cc
# [1196/1944] Compiling src/internet/model/ipv6-option-header.cc
# [1197/1944] Compiling src/internet/model/loopback-net-device.cc
# [1198/1944] Compiling src/internet/model/ipv6-option.cc
# [1199/1944] Compiling src/internet/model/ipv6-extension-demux.cc
# [1200/1944] Compiling src/internet/model/icmpv6-l4-protocol.cc
# [1201/1944] Compiling src/internet/model/ipv6-extension-header.cc
# [1202/1944] Compiling src/internet/model/ipv4-global-routing.cc
# [1203/1944] Compiling src/internet/model/candidate-queue.cc
# [1204/1944] Compiling src/internet/model/ipv6-extension.cc
# [1205/1944] Compiling src/internet/model/icmpv4-l4-protocol.cc
# [1206/1944] Compiling src/internet/model/global-route-manager-impl.cc

# %% [markdown]
# Os arquivos **.sh** acima chamam as simulações uma a uma, guardando o resultados no seguintes arquivos e pastas:
#
# - **./ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices**: para simulações variando o parâmetros **nDevices**;
#     - **campanha_1_local_nDevices.txt**: para resultados de simulação do arquivo **campanha_1.yaml**;
#     - **campanha_2_local_nDevices.txt**: para resultados de simulação do arquivo **campanha_2.yaml**;
#
#
# - **./ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius**: para simulações variando o parâmetros **radius**;
#     - **campanha_1_local_radius.txt**: para resultados de simulação do arquivo **campanha_1.yaml**;
#     - **campanha_2_local_radius.txt**: para resultados de simulação do arquivo **campanha_2.yaml**;

# %% [markdown]
# Abaixo, o script **loraScript.py** é chamado para criar a outra campanha de simulações criada anteriormente (**campanha_2.yaml**).

# %%
# %run loraScript -f "campanha_2.yaml"
# Out:
# Simulação escolhida:
# ['radius', 'nDevices']
# radius campaign written in file: run_campanha_2_local_radius.sh
# nDevices campaign written in file: run_campanha_2_local_nDevices.sh

# %% [markdown]
# O código a seguir executa o arquivo **.sh** da **campanha_2.yaml**, diretamente deste Jupyter Notebook. A saída foi suprimida para não poluir o documento.

# %%
# Comandos da campanha 1
# !chmod +x ./run_all_campanha_2_local_nDevices.sh
# !./run_all_campanha_2_local_nDevices.sh

# !chmod +x ./run_all_campanha_2_local_radius.sh
# !./run_all_campanha_2_local_radius.sh
# Out:
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.323s)
# simulation start at: Fri Oct  4 08:38:37 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 08:38:50 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.571s)
# simulation start at: Fri Oct  4 08:38:54 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 08:39:47 2019
#
# Time elapsed: 0.883333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.421s)
# simulation start at: Fri Oct  4 08:39:51 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 08:41:58 2019
#
# Time elapsed: 2.11667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.347s)
# simulation start at: Fri Oct  4 08:42:02 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 08:45:50 2019
#
# Time elapsed: 3.8 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.255s)
# simulation start at: Fri Oct  4 08:45:53 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 08:52:02 2019
#
# Time elapsed: 6.15 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.420s)
# simulation start at: Fri Oct  4 08:52:06 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:00:57 2019
#
# Time elapsed: 8.85 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.235s)
# simulation start at: Fri Oct  4 09:01:01 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:01:13 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.428s)
# simulation start at: Fri Oct  4 09:01:17 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:02:11 2019
#
# Time elapsed: 0.9 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.399s)
# simulation start at: Fri Oct  4 09:02:15 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:04:21 2019
#
# Time elapsed: 2.1 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.398s)
# simulation start at: Fri Oct  4 09:04:25 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:08:15 2019
#
# Time elapsed: 3.83333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.409s)
# simulation start at: Fri Oct  4 09:08:19 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:14:23 2019
#
# Time elapsed: 6.06667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.423s)
# simulation start at: Fri Oct  4 09:14:27 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:23:21 2019
#
# Time elapsed: 8.9 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.398s)
# simulation start at: Fri Oct  4 09:23:24 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:23:37 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.245s)
# simulation start at: Fri Oct  4 09:23:41 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:24:35 2019
#
# Time elapsed: 0.9 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.413s)
# simulation start at: Fri Oct  4 09:24:39 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:26:46 2019
#
# Time elapsed: 2.11667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.400s)
# simulation start at: Fri Oct  4 09:26:49 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:30:36 2019
#
# Time elapsed: 3.78333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.398s)
# simulation start at: Fri Oct  4 09:30:40 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:36:46 2019
#
# Time elapsed: 6.1 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.216s)
# simulation start at: Fri Oct  4 09:36:50 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:45:41 2019
#
# Time elapsed: 8.85 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.439s)
# simulation start at: Fri Oct  4 09:45:45 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:45:59 2019
#
# Time elapsed: 0.233333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.724s)
# simulation start at: Fri Oct  4 09:46:03 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:46:57 2019
#
# Time elapsed: 0.9 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.417s)
# simulation start at: Fri Oct  4 09:47:01 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:49:06 2019
#
# Time elapsed: 2.08333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.373s)
# simulation start at: Fri Oct  4 09:49:10 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:53:03 2019
#
# Time elapsed: 3.88333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.400s)
# simulation start at: Fri Oct  4 09:53:07 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 09:59:11 2019
#
# Time elapsed: 6.06667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.428s)
# simulation start at: Fri Oct  4 09:59:15 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:08:02 2019
#
# Time elapsed: 8.78333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.358s)
# simulation start at: Fri Oct  4 10:08:06 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:08:18 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.228s)
# simulation start at: Fri Oct  4 10:08:22 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:09:17 2019
#
# Time elapsed: 0.916667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.438s)
# simulation start at: Fri Oct  4 10:09:21 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:11:28 2019
#
# Time elapsed: 2.11667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.447s)
# simulation start at: Fri Oct  4 10:11:32 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:15:25 2019
#
# Time elapsed: 3.88333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.423s)
# simulation start at: Fri Oct  4 10:15:29 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:21:31 2019
#
# Time elapsed: 6.03333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.427s)
# simulation start at: Fri Oct  4 10:21:35 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 3166763426, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:30:34 2019
#
# Time elapsed: 8.98333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.398s)
# simulation start at: Fri Oct  4 10:30:37 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:30:50 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.406s)
# simulation start at: Fri Oct  4 10:30:54 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:31:47 2019
#
# Time elapsed: 0.883333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.416s)
# simulation start at: Fri Oct  4 10:31:51 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:34:01 2019
#
# Time elapsed: 2.16667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.428s)
# simulation start at: Fri Oct  4 10:34:05 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:37:54 2019
#
# Time elapsed: 3.81667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.353s)
# simulation start at: Fri Oct  4 10:37:58 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:44:07 2019
#
# Time elapsed: 6.15 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.246s)
# simulation start at: Fri Oct  4 10:44:10 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:53:05 2019
#
# Time elapsed: 8.91667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.399s)
# simulation start at: Fri Oct  4 10:53:09 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:53:22 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.410s)
# simulation start at: Fri Oct  4 10:53:26 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:54:20 2019
#
# Time elapsed: 0.9 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.341s)
# simulation start at: Fri Oct  4 10:54:24 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 10:56:29 2019
#
# Time elapsed: 2.08333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.577s)
# simulation start at: Fri Oct  4 10:56:33 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:00:22 2019
#
# Time elapsed: 3.81667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.403s)
# simulation start at: Fri Oct  4 11:00:26 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:06:34 2019
#
# Time elapsed: 6.13333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.484s)
# simulation start at: Fri Oct  4 11:06:38 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:15:35 2019
#
# Time elapsed: 8.95 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.416s)
# simulation start at: Fri Oct  4 11:15:39 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:15:51 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.445s)
# simulation start at: Fri Oct  4 11:15:55 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:16:49 2019
#
# Time elapsed: 0.9 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.326s)
# simulation start at: Fri Oct  4 11:16:53 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:18:59 2019
#
# Time elapsed: 2.1 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.398s)
# simulation start at: Fri Oct  4 11:19:03 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:22:50 2019
#
# Time elapsed: 3.78333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.418s)
# simulation start at: Fri Oct  4 11:22:54 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:28:59 2019
#
# Time elapsed: 6.08333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.433s)
# simulation start at: Fri Oct  4 11:29:03 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:38:02 2019
#
# Time elapsed: 8.98333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.414s)
# simulation start at: Fri Oct  4 11:38:06 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:38:19 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.520s)
# simulation start at: Fri Oct  4 11:38:23 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:39:16 2019
#
# Time elapsed: 0.883333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.417s)
# simulation start at: Fri Oct  4 11:39:20 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:41:27 2019
#
# Time elapsed: 2.11667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.357s)
# simulation start at: Fri Oct  4 11:41:31 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:45:19 2019
#
# Time elapsed: 3.8 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.446s)
# simulation start at: Fri Oct  4 11:45:23 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 11:51:25 2019
#
# Time elapsed: 6.03333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.566s)
# simulation start at: Fri Oct  4 11:51:29 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:00:17 2019
#
# Time elapsed: 8.8 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.282s)
# simulation start at: Fri Oct  4 12:00:20 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:00:33 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.413s)
# simulation start at: Fri Oct  4 12:00:37 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:01:31 2019
#
# Time elapsed: 0.9 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.413s)
# simulation start at: Fri Oct  4 12:01:35 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:03:42 2019
#
# Time elapsed: 2.11667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.402s)
# simulation start at: Fri Oct  4 12:03:46 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:07:36 2019
#
# Time elapsed: 3.83333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.249s)
# simulation start at: Fri Oct  4 12:07:39 2019
#
# Running with nDevices = 5000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:13:43 2019
#
# Time elapsed: 6.06667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.409s)
# simulation start at: Fri Oct  4 12:13:46 2019
#
# Running with nDevices = 6000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 4136715546, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:22:42 2019
#
# Time elapsed: 8.93333 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.360s)
# simulation start at: Fri Oct  4 12:22:46 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1920257470, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:22:58 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.409s)
# simulation start at: Fri Oct  4 12:23:02 2019
#
# Running with nDevices = 2000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1920257470, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:23:57 2019
#
# Time elapsed: 0.916667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.252s)
# simulation start at: Fri Oct  4 12:24:01 2019
#
# Running with nDevices = 3000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1920257470, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:26:08 2019
#
# Time elapsed: 2.11667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.423s)
# simulation start at: Fri Oct  4 12:26:12 2019
#
# Running with nDevices = 4000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 1920257470, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Fri Oct  4 12:30:01 2019
#
# Time elapsed: 3.81667 minutes
# ...
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:23:58 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.413s)
# simulation start at: Sat Oct  5 04:24:02 2019
#
# Running with nDevices = 1000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 1, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:24:14 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.330s)
# simulation start at: Sat Oct  5 04:24:18 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:24:30 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.568s)
# simulation start at: Sat Oct  5 04:24:34 2019
#
# Running with nDevices = 1000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:24:46 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.450s)
# simulation start at: Sat Oct  5 04:24:50 2019
#
# Running with nDevices = 1000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:25:03 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.399s)
# simulation start at: Sat Oct  5 04:25:07 2019
#
# Running with nDevices = 1000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:25:20 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.299s)
# simulation start at: Sat Oct  5 04:25:23 2019
#
# Running with nDevices = 1000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 2, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:25:35 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.402s)
# simulation start at: Sat Oct  5 04:25:39 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:25:52 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.493s)
# simulation start at: Sat Oct  5 04:25:56 2019
#
# Running with nDevices = 1000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:26:08 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.284s)
# simulation start at: Sat Oct  5 04:26:12 2019
#
# Running with nDevices = 1000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:26:24 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.253s)
# simulation start at: Sat Oct  5 04:26:28 2019
#
# Running with nDevices = 1000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:26:40 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.414s)
# simulation start at: Sat Oct  5 04:26:44 2019
#
# Running with nDevices = 1000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 3, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:26:56 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.380s)
# simulation start at: Sat Oct  5 04:27:00 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:27:12 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.405s)
# simulation start at: Sat Oct  5 04:27:16 2019
#
# Running with nDevices = 1000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:27:29 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.420s)
# simulation start at: Sat Oct  5 04:27:33 2019
#
# Running with nDevices = 1000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:27:45 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.386s)
# simulation start at: Sat Oct  5 04:27:49 2019
#
# Running with nDevices = 1000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:28:02 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.550s)
# simulation start at: Sat Oct  5 04:28:06 2019
#
# Running with nDevices = 1000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 4, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:28:19 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.427s)
# simulation start at: Sat Oct  5 04:28:23 2019
#
# Running with nDevices = 1000, radius = 2000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:28:35 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.427s)
# simulation start at: Sat Oct  5 04:28:39 2019
#
# Running with nDevices = 1000, radius = 4000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:28:52 2019
#
# Time elapsed: 0.216667 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.454s)
# simulation start at: Sat Oct  5 04:28:56 2019
#
# Running with nDevices = 1000, radius = 6000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:29:08 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.423s)
# simulation start at: Sat Oct  5 04:29:12 2019
#
# Running with nDevices = 1000, radius = 8000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:29:24 2019
#
# Time elapsed: 0.2 minutes
# Waf: Entering directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Waf: Leaving directory `/home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/build'
# Build commands will be stored in build/compile_commands.json
# 'build' finished successfully (3.424s)
# simulation start at: Sat Oct  5 04:29:28 2019
#
# Running with nDevices = 1000, radius = 10000 m, simulation Time =600 s, appPeriodSeconds = 600 s, Algoritmo ADR = 5, seed = 1, run stream = 2670870048, outputDir = /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius
# Completed configuration
# Running simulation...
# Computing performance metrics...
# simulation finished at: Sat Oct  5 04:29:41 2019
#
# Time elapsed: 0.216667 minutes

# %% [markdown]
# # Plotar gráficos
#
# Para plotar gráficos, chamaremos o mesmo arquivo **yaml** que foi usado para criar as campanhas de simulação. Um novo script chamado **plotScript.py** foi construído para esse fim. Ao executar esse código no Jupyter Notebook (Shift+Enter), o arquivo **plotScript.py** é gerado.

# %%
# %%file plotScript.py
# Legend
#   RunSeed: 0
#   Seed: 1
#   Algoritmo: 2
#   Radius: 3
#   nDevices: 4
#   appPeriodSeconds:5
#   simulationTime:6
#   PHYTotal: 7
#   PHYSuccessful:8 
#   PHYInterfered: 9
#   PHYNoMoreReceivers: 10
#   PHYUnderSensitivity: 11
#   PHYLostBecauseTX: 12
#   SimulationDuration: 13

import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
import scipy.stats as st
import os
import argparse
import yaml
import matplotlib

class openSimulation:
    def __init__(self, configurations_file):
        self.email_to = 'martinsdecastro23@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.showPlot = True;
        self.plotCI = True;                
        self.campaign = self.doc['scenario']['campaign']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.simulationTime = self.doc['scenario']['simulationTime']
        self.nDevices = self.doc['scenario']['nDevices']
        self.nDevices = list(map(float,self.nDevices))
        self.radius = self.doc['scenario']['radius']
        self.radius = list(map(float,self.radius))
        self.appPeriodSeconds = self.doc['scenario']['appPeriodSeconds']
        self.bPrint = (self.doc['scenario']['bPrint'])
        self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.algoritmo = self.doc['scenario']['Algoritmo']
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        if self.nJobs == 1: # disable the confidence interval
            self.plotCI = False;
        self.filename = str(self.doc['scenario']['filename'])
        
    def plotCampaign(self,curCampaign, metric):
        # some general configurations
        outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign        
        chFile = outputDir+ "/" + self.filename + '.txt'        
        print(chFile)
        simTime = np.loadtxt(chFile, skiprows=1, usecols=(6, ), delimiter=',', unpack=False)                
        resalg = np.loadtxt(chFile, skiprows=1, usecols=(2, ), delimiter=',', unpack=False)
        resradius = np.loadtxt(chFile, skiprows=1, usecols=(3, ), delimiter=',', unpack=False)
        resnDevices = np.loadtxt(chFile, skiprows=1, usecols=(4, ), delimiter=',', unpack=False)
        ressimDur = np.loadtxt(chFile, skiprows=1, usecols=(13, ), delimiter=',', unpack=False)
        resphyTotal = np.loadtxt(chFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
        resphySucc = np.loadtxt(chFile, skiprows=1, usecols=(8, ), delimiter=',', unpack=False)
            
        markersA = cycle(('o', 'v', '^', 's', '>', 'p', '*', 'h', '<', 'H', 'D', 'd'))
        colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))                    
        plt.figure()     
        for iAlg in self.algoritmo:
            m_plr, m_plrCI, m_tput, m_tputCI, m_pkt, m_pktCI = [], [], [], [], [], []
            for varParam in self.doc['scenario'][curCampaign]:                
                if str(curCampaign) == 'radius':
                    resalgIndexs = (resalg == int(iAlg)) & (resradius == int(varParam))
                    xlabel='Distância [m]'
                    resxData = self.radius; 
                elif str(curCampaign) == 'nDevices':
                    resalgIndexs = (resalg == int(iAlg)) & (resnDevices == int(varParam))                    
                    xlabel='Quantidade de Dispositivos'
                    resxData = self.nDevices;
                # Plr Evaluation
                label = "ADR_"+iAlg
                color=next(colors)
                marker=next(markersA)
                if metric=='PLR':                
                    # Calculate PLR line
                    plr = 100*( resphyTotal[resalgIndexs]-resphySucc[resalgIndexs] ) / resphyTotal[resalgIndexs]
                    m_plr = np.append(m_plr, np.mean(plr))
                    # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                    l, h = st.t.interval(0.95, len(plr)-1, loc=np.mean(plr), scale=st.sem(plr))
                    #l,h = st.norm.interval(0.95, loc=np.mean(plr), scale=st.sem(plr))                                                            
                    m_plrCI = np.append(m_plrCI, h)
                elif metric=='Tput':
                    # TODO
                    # Calculate PLR line
                    tput = 23*( resphySucc[resalgIndexs] ) / float(self.simulationTime)
                    m_tput = np.append(m_tput, np.mean(tput))
                    # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                    l, h = st.t.interval(0.95, len(tput)-1, loc=np.mean(tput), scale=st.sem(tput))
                    #l,h = st.norm.interval(0.95, loc=np.mean(tput), scale=st.sem(tput))                    
                    m_tputCI = np.append(m_tputCI, h)
                elif metric=='Pkt':
                    # TODO
                    # Calculate PLR line
                    pkt = 100 * ( resphySucc[resalgIndexs] ) / resphyTotal[resalgIndexs]
                    m_pkt = np.append(m_pkt, np.mean(pkt))
                    # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                    l, h = st.t.interval(0.95, len(pkt)-1, loc=np.mean(pkt), scale=st.sem(pkt))
                    #l,h = st.norm.interval(0.95, loc=np.mean(pkt), scale=st.sem(pkt))                    
                    m_pktCI = np.append(m_pktCI, h)

                
            # Plot line
            if metric=='PLR':                         
                plt.plot(resxData,m_plr, label=label, marker=marker,color=color)   
                if bool(self.plotCI):
                    plt.errorbar(resxData,m_plr, yerr=(m_plrCI-m_plr), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2)
            elif metric=='Tput':
                # TODO
                plt.plot(resxData,m_tput, label=label, marker=marker,color=color)    
                if bool(self.plotCI):                
                    plt.errorbar(resxData,m_tput, yerr = (m_tputCI-m_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2)
            elif metric=='Pkt':
                # TODO
                plt.plot(resxData,m_pkt, label=label, marker=marker,color=color)    
                if bool(self.plotCI):                
                    plt.errorbar(resxData,m_pkt, yerr = (m_pktCI-m_pkt), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2)
            
        # Plot figure
        params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
        plt.rcParams.update(params)        
        os.makedirs(outputDir+"/ps", exist_ok=True)
        os.makedirs(outputDir+"/png", exist_ok=True)
        
        if metric=='PLR':        
            # Show and save PLR plot
            ylabel="PLR [%]"
            plt.xlabel(xlabel)
            plt.ylabel(ylabel)
            plt.legend(loc='best', numpoints=1)        
            plt.grid()
            plt.tight_layout()
            if bool(self.plotCI):
                imgfilename = 'PLR_CI_'+curCampaign
            else:
                imgfilename = 'PLR_'+curCampaign
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()
        elif metric=='Tput':
            # TODO
            # Show and save PLR plot
            ylabel="Tput [bps]"
            plt.xlabel(xlabel)
            plt.ylabel(ylabel)
            plt.legend(loc='best', numpoints=1)        
            plt.grid()
            plt.tight_layout()
            if bool(self.plotCI):
                imgfilename = 'TPUT_CI_'+curCampaign
            else:
                imgfilename = 'TPUT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()

        elif metric=='Pkt':
            # TODO
            # Show and save PLR plot
            ylabel="Pacotes recebidos [%]"
            plt.xlabel(xlabel)
            plt.ylabel(ylabel)
            #plt.legend(loc='upper left', numpoints=1)        
            plt.legend(loc='best', numpoints=1)        
            plt.grid()
            plt.tight_layout()
            if bool(self.plotCI):
                imgfilename = 'PKT_CI_'+curCampaign
            else:
                imgfilename = 'PKT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()

parser = argparse.ArgumentParser()
parser.add_argument("-f", "--file", type=str, help='Configuration File')
args = parser.parse_args()

configurations_file = args.file; 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]

# print(doc)
print('Simulação escolhida: ')
campaign = doc['scenario']['campaign']
print(campaign)
                 
simu = openSimulation(configurations_file)
for iMet in ['PLR', 'Tput', 'Pkt','Stime']:
    for simC in campaign:
        if str(simC) == 'nDevices' or str(simC) == 'radius':
            simu.plotCampaign(simC,iMet);
        else:
            print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting plotScript.py

# %% [markdown]
# Abaixo, o script **plotScript.py** é chamado para a **campanha_1.yaml** criada e simulada anteriormente.

# %%
# %run plotScript -f "campanha_1.yaml"
# Out:
# Simulação escolhida:
# ['radius', 'nDevices']
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_1_job.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_1_job.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_1_job.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_1_job.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_1_job.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_1_job.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_1_job.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_1_job.txt

# %% [markdown]
# Como a **campanha_1.yaml** foi realizada somente com 1 job (um experimento de Monte Carlo), as figuras não mostram o intervalo de confiança.

# %% [markdown]
# A seguir, o script **plotScript.py** é chamado para plotar os gráficos da outra campanha de simulações criada anteriormente (**campanha_2.yaml**). Como mais de 1 job foi simulado, as figuras mostram o intervalo de confiança para 95% confiança, significando que ao executar o mesmo experimento, a média estará dentro de intervalo informado em 95% das vezes.

# %% [markdown]
# Para a **campanha_2.yaml** (com 10 jobs):

# %%
# %run plotScript -f "campanha_2.yaml"
# Out:
# Simulação escolhida:
# ['radius', 'nDevices']
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_10_jobs.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_10_jobs.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_10_jobs.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_10_jobs.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_10_jobs.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_10_jobs.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_radius/DadosLora_10_jobs.txt
# /home/gppcom/ns_3_lora/ns-3-lora-gppcom/ns-allinone-3.29/ns-3.29/results_local_nDevices/DadosLora_10_jobs.txt

# %% [markdown]
# É possível abservar que o intervalo de confiana já é bem pequeno para 10 jobs.
